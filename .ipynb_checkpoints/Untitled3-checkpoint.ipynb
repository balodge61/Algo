# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /Users/seanmorey/opt/anaconda3/lib/python3.7/site-packages (0.1.55)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/seanmorey/opt/anaconda3/lib/python3.7/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: pandas>=0.24 in /Users/seanmorey/opt/anaconda3/lib/python3.7/site-packages (from yfinance) (1.1.5)
# Requirement already satisfied: lxml>=4.5.1 in /Users/seanmorey/opt/anaconda3/lib/python3.7/site-packages (from yfinance) (4.6.2)
# Requirement already satisfied: requests>=2.20 in /Users/seanmorey/opt/anaconda3/lib/python3.7/site-packages (from yfinance) (2.22.0)
# Requirement already satisfied: numpy>=1.15 in /Users/seanmorey/opt/anaconda3/lib/python3.7/site-packages (from yfinance) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/seanmorey/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/seanmorey/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.24->yfinance) (2019.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/seanmorey/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.20->yfinance) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/seanmorey/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.20->yfinance) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/seanmorey/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.20->yfinance) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/seanmorey/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: six>=1.5 in /Users/seanmorey/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
stock_list = ["MLR","HCA","LPX", "KO", "PEP", "GS", "JPM"]
stock = "SPY"
period = "60d"
interval = "30m"
stock1 = yf.Ticker(stock)
stock1_price = stock1.history(period=period, interval=interval)
stock1_df = pd.DataFrame(stock1_price.Close).rename(columns={"Close": stock})
df = stock1_df

for stock in stock_list:
    print("Starting stock: ", stock)
    stock2 = yf.Ticker(stock)
    print("Got stock: ", stock)
    stock2_price = stock2.history(period=period, interval=interval)
    stock2_df = pd.DataFrame(stock2_price.Close).rename(columns={"Close": stock})
    df = df.merge(stock2_df, left_on='Datetime', right_on='Datetime')
    
df.head()
# Out:
# Starting stock:  MLR
# Got stock:  MLR
# Starting stock:  HCA
# Got stock:  HCA
# Starting stock:  LPX
# Got stock:  LPX
# Starting stock:  KO
# Got stock:  KO
# Starting stock:  PEP
# Got stock:  PEP
# Starting stock:  GS
# Got stock:  GS
# Starting stock:  JPM
# Got stock:  JPM
#                                   SPY        MLR         HCA        LPX  \
# Datetime
# 2020-12-01 09:30:00-05:00  366.160095  33.910000  152.750000  34.799999
# 2020-12-01 10:00:00-05:00  366.975586  34.410000  152.729996  34.849998
# 2020-12-01 10:30:00-05:00  366.290009  34.270000  152.470001  34.669998
# 2020-12-01 11:00:00-05:00  366.649994  34.029999  151.925003  34.549999
# 2020-12-01 11:30:00-05:00  366.269897  33.860001  151.279999  34.400002
#
#                                   KO         PEP          GS         JPM
# Datetime
# 2020-12-01 09:30:00-05:00  51.849998  145.164993  234.440002  120.695000
# 2020-12-01 10:00:00-05:00  52.230000  145.880005  234.210007  120.589996
# 2020-12-01 10:30:00-05:00  52.169998  145.800003  233.750000  120.830002
# 2020-12-01 11:00:00-05:00  52.143501  145.789993  234.419998  121.190002
# 2020-12-01 11:30:00-05:00  52.110001  145.589996  232.549698  120.400002

# %%
df.corr()
# Out:
#           SPY       MLR       HCA       LPX        KO       PEP        GS  \
# SPY  1.000000  0.863566  0.852278  0.761471 -0.670492 -0.778872  0.888290
# MLR  0.863566  1.000000  0.789806  0.615806 -0.803815 -0.716290  0.892889
# HCA  0.852278  0.789806  1.000000  0.766500 -0.536631 -0.680718  0.888575
# LPX  0.761471  0.615806  0.766500  1.000000 -0.382307 -0.874865  0.773139
# KO  -0.670492 -0.803815 -0.536631 -0.382307  1.000000  0.649381 -0.707927
# PEP -0.778872 -0.716290 -0.680718 -0.874865  0.649381  1.000000 -0.827459
# GS   0.888290  0.892889  0.888575  0.773139 -0.707927 -0.827459  1.000000
# JPM  0.880197  0.823459  0.855842  0.807672 -0.649696 -0.850878  0.980389
#
#           JPM
# SPY  0.880197
# MLR  0.823459
# HCA  0.855842
# LPX  0.807672
# KO  -0.649696
# PEP -0.850878
# GS   0.980389
# JPM  1.000000

# %%
period = "60d"
interval = "5m"
stock = yf.Ticker("JPM")
df = stock.history(period=period, interval=interval)

df = df.replace(to_replace = 0, value =1) 
df = df.drop(['Dividends','Stock Splits'], axis = 1)

cols_pct_change = ["Close", "Volume"]
col_names = []

def target(future_close_pc):
    if future_close_pc >= .1:
        return 1
    else:
        return 0

for col in cols_pct_change:
    for i in np.arange(1,5):
        col_name = f"{col}_{i}p_pc"
        df[col_name] = df[col].pct_change(periods=i)*100
        col_names.append(col_name)
    for i in np.arange(-4, 0):
        if col == "Close":
            df[f"{col}_f{-i}p_pc"] = df[col].pct_change(periods=i)*100
df.head()
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2020-12-01 09:30:00-05:00  120.339996  120.489998  119.769997  119.809998
# 2020-12-01 09:35:00-05:00  119.834999  120.550003  119.650002  120.500000
# 2020-12-01 09:40:00-05:00  120.449997  120.620003  120.260002  120.459900
# 2020-12-01 09:45:00-05:00  120.419998  120.570000  120.169998  120.290001
# 2020-12-01 09:50:00-05:00  120.279999  120.750000  120.129997  120.544998
#
#                            Volume  Close_1p_pc  Close_2p_pc  Close_3p_pc  \
# Datetime
# 2020-12-01 09:30:00-05:00  671257          NaN          NaN          NaN
# 2020-12-01 09:35:00-05:00  248768     0.575914          NaN          NaN
# 2020-12-01 09:40:00-05:00  237999    -0.033278     0.542444          NaN
# 2020-12-01 09:45:00-05:00  204295    -0.141042    -0.174273     0.400637
# 2020-12-01 09:50:00-05:00  248600     0.211985     0.070644     0.037343
#
#                            Close_4p_pc  Close_f4p_pc  Close_f3p_pc  \
# Datetime
# 2020-12-01 09:30:00-05:00          NaN     -0.609731     -0.399038
# 2020-12-01 09:35:00-05:00          NaN     -0.161564     -0.037329
# 2020-12-01 09:40:00-05:00          NaN     -0.372263     -0.194788
# 2020-12-01 09:45:00-05:00          NaN     -0.215680     -0.512780
# 2020-12-01 09:50:00-05:00     0.613472     -0.103753     -0.004152
#
#                            Close_f2p_pc  Close_f1p_pc  Volume_1p_pc  \
# Datetime
# 2020-12-01 09:30:00-05:00     -0.539518     -0.572616           NaN
# 2020-12-01 09:35:00-05:00      0.174577      0.033289    -62.939977
# 2020-12-01 09:40:00-05:00     -0.070595      0.141241     -4.328933
# 2020-12-01 09:45:00-05:00     -0.335556     -0.211537    -14.161404
# 2020-12-01 09:50:00-05:00     -0.301882     -0.124281     21.686776
#
#                            Volume_2p_pc  Volume_3p_pc  Volume_4p_pc
# Datetime
# 2020-12-01 09:30:00-05:00           NaN           NaN           NaN
# 2020-12-01 09:35:00-05:00           NaN           NaN           NaN
# 2020-12-01 09:40:00-05:00    -64.544280           NaN           NaN
# 2020-12-01 09:45:00-05:00    -17.877299    -69.565308           NaN
# 2020-12-01 09:50:00-05:00      4.454220     -0.067533    -62.965004

# %%
df = df.dropna() 
print(df.shape)
df.head()
# Out:
# (4635, 17)
#                                  Open        High         Low       Close  \
# Datetime
# 2020-12-01 09:50:00-05:00  120.279999  120.750000  120.129997  120.544998
# 2020-12-01 09:55:00-05:00  120.519997  120.779999  120.390099  120.695000
# 2020-12-01 10:00:00-05:00  120.690002  120.959999  120.580002  120.910004
# 2020-12-01 10:05:00-05:00  120.915001  120.915001  120.519997  120.550003
# 2020-12-01 10:10:00-05:00  120.553200  120.809998  120.529999  120.670197
#
#                            Volume  Close_1p_pc  Close_2p_pc  Close_3p_pc  \
# Datetime
# 2020-12-01 09:50:00-05:00  248600     0.211985     0.070644     0.037343
# 2020-12-01 09:55:00-05:00  248477     0.124436     0.336685     0.195169
# 2020-12-01 10:00:00-05:00  144652     0.178138     0.302796     0.515423
# 2020-12-01 10:05:00-05:00  125575    -0.297743    -0.120135     0.004152
# 2020-12-01 10:10:00-05:00  115883     0.099704    -0.198335    -0.020550
#
#                            Close_4p_pc  Close_f4p_pc  Close_f3p_pc  \
# Datetime
# 2020-12-01 09:50:00-05:00     0.613472     -0.103753     -0.004152
# 2020-12-01 09:55:00-05:00     0.161825      0.008288      0.020555
# 2020-12-01 10:00:00-05:00     0.373654     -0.066116      0.186441
# 2020-12-01 10:05:00-05:00     0.216146     -0.033165     -0.363662
# 2020-12-01 10:10:00-05:00     0.103860     -0.037858      0.066507
#
#                            Close_f2p_pc  Close_f1p_pc  Volume_1p_pc  \
# Datetime
# 2020-12-01 09:50:00-05:00     -0.301882     -0.124281     21.686776
# 2020-12-01 09:55:00-05:00      0.120279     -0.177821     -0.049477
# 2020-12-01 10:00:00-05:00      0.198729      0.298632    -41.784551
# 2020-12-01 10:05:00-05:00     -0.111857     -0.099605    -13.188203
# 2020-12-01 10:10:00-05:00     -0.264320     -0.012264     -7.718097
#
#                            Volume_2p_pc  Volume_3p_pc  Volume_4p_pc
# Datetime
# 2020-12-01 09:50:00-05:00      4.454220     -0.067533    -62.965004
# 2020-12-01 09:55:00-05:00     21.626569      4.402540     -0.116976
# 2020-12-01 10:00:00-05:00    -41.813355    -29.194547    -39.221593
# 2020-12-01 10:05:00-05:00    -49.462123    -49.487128    -38.532514
# 2020-12-01 10:10:00-05:00    -19.888422    -53.362685    -53.385760

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

model = LinearRegression()


X = df[['Open','High','Low','Close','Volume'] + col_names]
y = df['Close_f1p_pc']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

model.fit(X_train, y_train)

predictions = model.predict(X_test)
MSE = mean_squared_error(y_test, predictions)
r2 = model.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")
print(predictions)
print(model.coef_)
# Out:
# MSE: 286.9180493162504, R2: -7125.5485613029
# [-0.01333909 -0.01035271  0.00368163 ...  0.00712869  0.00909585
#   0.01561983]
# [ 3.10848894e-02 -2.10965361e-02 -1.30874067e-01  1.21033504e-01
#  -1.54357876e-07  5.92970937e-02 -2.69886362e-02  5.86905673e-03
#   3.19946176e-03  2.35074266e-08  2.39816840e-09 -5.27948021e-05
#  -5.64678690e-09]

# %%
pd.DataFrame([predictions, y])
# Out:
#        0         1         2         3         4         5         6     \
# 0 -0.013339 -0.010353  0.003682  0.031997 -0.010284  0.009331  0.018020
# 1 -0.124281 -0.177821  0.298632 -0.099605 -0.012264 -0.252087  0.331704
#
#        7         8         9     ...     4625      4626      4627      4628  \
# 0 -0.013707  0.012692 -0.002064  ...      NaN       NaN       NaN       NaN
# 1 -0.104295 -0.135755 -0.082663  ... -0.00675 -0.204543 -0.061633  0.067403
#
#        4629      4630      4631      4632      4633      4634
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1 -0.067358  0.107885  0.226384 -0.097886  0.054041 -0.168589
#
# [2 rows x 4635 columns]
